# %%
# from shutil import copyfile
# copyfile('../unit2/people.csv', 'people.csv')

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
people = pd.read_csv('people.csv')
people
# Out:
#       name   gpa       sport  footware  height  friends
# 0   dakota  3.15  basketball  sneakers      72      307
# 1  charlie  1.10    baseball   sandals      61       34
# 2   hayden  3.50      tennis   sandals      68      335
# 3   kamryn  2.18      soccer  sneakers      66      200
# 4  emerson  3.06      soccer  sneakers      65      213
# 5   jessie  2.41  basketball   sandals      61      202
# 6   sawyer  2.96      tennis   sandals      67      314
# 7   london  3.98      soccer  sneakers      64      436

# %%
plt.scatter(people.friends, people.height)

# %%
plt.scatter(people.friends, people.height)

plt.grid()
plt.xlabel('Friends')
plt.ylabel('Height')

# %%
xpoints = np.array([400,50])
ypoints = np.array([70,61])

plt.scatter(people.friends, people.height)

plt.grid()
plt.xlabel('Friends')
plt.ylabel('Height')

plt.plot(xpoints,ypoints)

# %%
people.corr()
# Out:
#               gpa    height   friends
# gpa      1.000000  0.502907  0.955895
# height   0.502907  1.000000  0.511286
# friends  0.955895  0.511286  1.000000

# %%
import seaborn as sns

sns.scatterplot(data=people, x='friends', y='height', hue='footware').grid()

# %%
sns.regplot(data=people, x='friends', y='height')
# Out:
# <AxesSubplot:xlabel='friends', ylabel='height'>

# %%
sns.lmplot(data=people, x='friends', y='height', hue='footware')
